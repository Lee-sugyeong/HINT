# %%
class Sensor:
    def __init__(self, sensor_id, value):
        self.sensor_id = sensor_id
        self.value = value
        
    def show(self):
        print(f"{self.sensor_id}, {self.value}")

s1 = Sensor("HI", 300)
s1.show()
# Out:
# HI, 300

# %%
class Sensor:
    def __init__(self, sensor_id):
        self.sensor_id = sensor_id

class TemperatureSensor(Sensor):
    def __init__(self, sensor_id, celsius):
        super().__init__(sensor_id)
    def to_fahrenheit(self):
        return self.celsius * 9 / 5 + 32

s1 = Sensor("HI", 300)
s1.show()
# Out:
# HI, 300

# %%
class Sensor:
    def __init__(self, sensor_id, value):
        self.sensor_id = sensor_id
        self.value = value
    def show(self):
        print(f"{self.sensor_id}, {self.value}")
    def

class HumiditySensor(Sensor):
    def __init__(self):
        return '24.5'

s1 = Sensor("HI", 300)
s1.show()

# %%
class Sensor():
    def __init__(self, sensor_id, value):
        self.sensor_id = sensor_id
        self.value = value
    def show(self):
        print(f"{self.sensor_id}, {self.value}")

s1 = Sensor("12ds", 50)
s1.show()
# Out:
# 12ds, 50

# %%
class Sensor():
    def __init__(self, sensor_id):
        self.sensor_id = sensor_id
        
class TemperatureSensor(Sensor):
    def __init__(self, sensor_id, celsius):
        super().__init__(sensor_id)
        self.celsius = celsius
    def to_fahrenheit(self):
        return self.celsius*9/5+32
        

s1 = TemperatureSensor("12RU", 30)
print(s1.sensor_id, s1.to_fahrenheit())
# Out:
# 12RU 86.0

# %%
class Sensor:
    def __init__(self, sensor_id):
        self.sensor_id = sensor_id

    def read(self):
        return '측정값 없음'


class TemperatureSensor(Sensor):
    def __init__(self, sensor_id, celsius):
        super().__init__(sensor_id)
        self.celsius = celsius

    def to_fahrenheit(self):
        return self.celsius * 9 / 5 + 32

    def read(self):
        return f'{self.celsius} C'


class HumiditySensor(Sensor):
    def __init__(self, sensor_id, value):
        super().__init__(sensor_id)
        self.value = value

    def read(self):
        return f'{self.value} %'


print(TemperatureSensor('T-01', 24.5).read())
print(HumiditySensor('H-01', 60).read())
# Out:
# 24.5 C
# 60 %

# %%
class Sensor:
    def read(self):
        return '측정값 없음'


class TemperatureSensor(Sensor):
    def __init__(self, value):
        self.value = value

    def read(self):
        return f'{self.value} C'


class HumiditySensor(Sensor):
    def __init__(self, value):
        self.value = value

    def read(self):
        return f'{self.value} %'

sensors = [TemperatureSensor(30), HumiditySensor(45)]
for sensor in sensors:
    print(sensor.read())
# Out:
# 30 C
# 45 %

# %%
class Sensor:
    def __init__(self, sensor_idm value):
        self.sensor_id = sensor_id
        self
